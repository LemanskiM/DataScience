# %%
import pandas as pd

# %%
fuel = pd.read_csv("C:\ML\paliwo.csv", low_memory=False, usecols= ['Vehicle ID','Year','Make','Model','Class','Fuel Type','Combined MPG (FT1)'] )

# %%
fuel.head()
# Out:
#    Vehicle ID  Year        Make               Model  \
# 0       26587  1984  Alfa Romeo           GT V6 2.5
# 1       27705  1984  Alfa Romeo           GT V6 2.5
# 2       26561  1984  Alfa Romeo  Spider Veloce 2000
# 3       27681  1984  Alfa Romeo  Spider Veloce 2000
# 4       27550  1984  AM General   DJ Po Vehicle 2WD
#
#                          Class Fuel Type  Combined MPG (FT1)
# 0             Minicompact Cars   Regular                20.0
# 1             Minicompact Cars   Regular                20.0
# 2                  Two Seaters   Regular                21.0
# 3                  Two Seaters   Regular                21.0
# 4  Special Purpose Vehicle 2WD   Regular                17.0

# %%
fuel["LperKm"] = fuel["Combined MPG (FT1)"] *1.609/3.78

# %%
fuel
# Out:
#        Vehicle ID  Year        Make               Model  \
# 0           26587  1984  Alfa Romeo           GT V6 2.5
# 1           27705  1984  Alfa Romeo           GT V6 2.5
# 2           26561  1984  Alfa Romeo  Spider Veloce 2000
# 3           27681  1984  Alfa Romeo  Spider Veloce 2000
# 4           27550  1984  AM General   DJ Po Vehicle 2WD
# ...           ...   ...         ...                 ...
# 31679       32060  2012  Mitsubishi              Lancer
# 31680       32063  2012  Mitsubishi          Lancer AWD
# 31681       32065  2012  Mitsubishi    Lancer Evolution
# 31682       32064  2012  Mitsubishi    Lancer Evolution
# 31683       32106  2012   Mitsubish                 NaN
#
#                              Class Fuel Type  Combined MPG (FT1)     LperKm
# 0                 Minicompact Cars   Regular                20.0   8.513228
# 1                 Minicompact Cars   Regular                20.0   8.513228
# 2                      Two Seaters   Regular                21.0   8.938889
# 3                      Two Seaters   Regular                21.0   8.938889
# 4      Special Purpose Vehicle 2WD   Regular                17.0   7.236243
# ...                            ...       ...                 ...        ...
# 31679                 Compact Cars   Regular                25.0  10.641534
# 31680                 Compact Cars   Regular                25.0  10.641534
# 31681                 Compact Cars   Premium                19.0   8.087566
# 31682                 Compact Cars   Premium                19.0   8.087566
# 31683                          NaN       NaN                 NaN        NaN
#
# [31684 rows x 8 columns]

# %%
fuel["bad"] = fuel.Year *2

# %%
fuel
# Out:
#        Vehicle ID  Year        Make               Model  \
# 0           26587  1984  Alfa Romeo           GT V6 2.5
# 1           27705  1984  Alfa Romeo           GT V6 2.5
# 2           26561  1984  Alfa Romeo  Spider Veloce 2000
# 3           27681  1984  Alfa Romeo  Spider Veloce 2000
# 4           27550  1984  AM General   DJ Po Vehicle 2WD
# ...           ...   ...         ...                 ...
# 31679       32060  2012  Mitsubishi              Lancer
# 31680       32063  2012  Mitsubishi          Lancer AWD
# 31681       32065  2012  Mitsubishi    Lancer Evolution
# 31682       32064  2012  Mitsubishi    Lancer Evolution
# 31683       32106  2012   Mitsubish                 NaN
#
#                              Class Fuel Type  Combined MPG (FT1)     LperKm  \
# 0                 Minicompact Cars   Regular                20.0   8.513228
# 1                 Minicompact Cars   Regular                20.0   8.513228
# 2                      Two Seaters   Regular                21.0   8.938889
# 3                      Two Seaters   Regular                21.0   8.938889
# 4      Special Purpose Vehicle 2WD   Regular                17.0   7.236243
# ...                            ...       ...                 ...        ...
# 31679                 Compact Cars   Regular                25.0  10.641534
# 31680                 Compact Cars   Regular                25.0  10.641534
# 31681                 Compact Cars   Premium                19.0   8.087566
# 31682                 Compact Cars   Premium                19.0   8.087566
# 31683                          NaN       NaN                 NaN        NaN
#
#         bad
# 0      3968
# 1      3968
# 2      3968
# 3      3968
# 4      3968
# ...     ...
# 31679  4024
# 31680  4024
# 31681  4024
# 31682  4024
# 31683  4024
#
# [31684 rows x 9 columns]

# %%
fuel.insert(loc =2, column = "per100", value =100 / fuel.LperKm )

# %%
fuel
# Out:
#        Vehicle ID  Year     per100        Make               Model  \
# 0           26587  1984  11.746426  Alfa Romeo           GT V6 2.5
# 1           27705  1984  11.746426  Alfa Romeo           GT V6 2.5
# 2           26561  1984  11.187073  Alfa Romeo  Spider Veloce 2000
# 3           27681  1984  11.187073  Alfa Romeo  Spider Veloce 2000
# 4           27550  1984  13.819325  AM General   DJ Po Vehicle 2WD
# ...           ...   ...        ...         ...                 ...
# 31679       32060  2012   9.397141  Mitsubishi              Lancer
# 31680       32063  2012   9.397141  Mitsubishi          Lancer AWD
# 31681       32065  2012  12.364659  Mitsubishi    Lancer Evolution
# 31682       32064  2012  12.364659  Mitsubishi    Lancer Evolution
# 31683       32106  2012        NaN   Mitsubish                 NaN
#
#                              Class Fuel Type  Combined MPG (FT1)     LperKm  \
# 0                 Minicompact Cars   Regular                20.0   8.513228
# 1                 Minicompact Cars   Regular                20.0   8.513228
# 2                      Two Seaters   Regular                21.0   8.938889
# 3                      Two Seaters   Regular                21.0   8.938889
# 4      Special Purpose Vehicle 2WD   Regular                17.0   7.236243
# ...                            ...       ...                 ...        ...
# 31679                 Compact Cars   Regular                25.0  10.641534
# 31680                 Compact Cars   Regular                25.0  10.641534
# 31681                 Compact Cars   Premium                19.0   8.087566
# 31682                 Compact Cars   Premium                19.0   8.087566
# 31683                          NaN       NaN                 NaN        NaN
#
#         bad
# 0      3968
# 1      3968
# 2      3968
# 3      3968
# 4      3968
# ...     ...
# 31679  4024
# 31680  4024
# 31681  4024
# 31682  4024
# 31683  4024
#
# [31684 rows x 10 columns]

# %%
del fuel ["Class"]

# %%
fuel
# Out:
#        Vehicle ID  Year     per100        Make               Model Fuel Type  \
# 0           26587  1984  11.746426  Alfa Romeo           GT V6 2.5   Regular
# 1           27705  1984  11.746426  Alfa Romeo           GT V6 2.5   Regular
# 2           26561  1984  11.187073  Alfa Romeo  Spider Veloce 2000   Regular
# 3           27681  1984  11.187073  Alfa Romeo  Spider Veloce 2000   Regular
# 4           27550  1984  13.819325  AM General   DJ Po Vehicle 2WD   Regular
# ...           ...   ...        ...         ...                 ...       ...
# 31679       32060  2012   9.397141  Mitsubishi              Lancer   Regular
# 31680       32063  2012   9.397141  Mitsubishi          Lancer AWD   Regular
# 31681       32065  2012  12.364659  Mitsubishi    Lancer Evolution   Premium
# 31682       32064  2012  12.364659  Mitsubishi    Lancer Evolution   Premium
# 31683       32106  2012        NaN   Mitsubish                 NaN       NaN
#
#        Combined MPG (FT1)     LperKm   bad
# 0                    20.0   8.513228  3968
# 1                    20.0   8.513228  3968
# 2                    21.0   8.938889  3968
# 3                    21.0   8.938889  3968
# 4                    17.0   7.236243  3968
# ...                   ...        ...   ...
# 31679                25.0  10.641534  4024
# 31680                25.0  10.641534  4024
# 31681                19.0   8.087566  4024
# 31682                19.0   8.087566  4024
# 31683                 NaN        NaN  4024
#
# [31684 rows x 9 columns]
