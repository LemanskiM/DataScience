# %%
import pandas as pd

# %%
professions = pd.read_csv("C:\ML\data\Prestige.csv",index_col=['name'])

# %%
professions1 = professions.copy()

# %%
professions.head()
# Out:
#                      education  income  women  prestige  census  type
# name
# gov.administrators       13.11   12351  11.16      68.8    1113  prof
# general.managers         12.26   25879   4.02      69.1    1130  prof
# accountants              12.77    9271  15.70      63.4    1171  prof
# purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# chemists                 14.62    8403  11.68      73.5    2111  prof

# %%
professions.rename(columns = {'income':'IncomeDollarsPerYear'})
# Out:
#                      education  IncomeDollarsPerYear  women  prestige  census  \
# name
# gov.administrators       13.11                 12351  11.16      68.8    1113
# general.managers         12.26                 25879   4.02      69.1    1130
# accountants              12.77                  9271  15.70      63.4    1171
# purchasing.officers      11.42                  8865   9.11      56.8    1175
# chemists                 14.62                  8403  11.68      73.5    2111
# ...                        ...                   ...    ...       ...     ...
# bus.drivers               7.58                  5562   9.47      35.9    9171
# taxi.drivers              7.93                  4224   3.59      25.1    9173
# longshoremen              8.37                  4753   0.00      26.1    9313
# typesetters              10.00                  6462  13.58      42.2    9511
# bookbinders               8.55                  3617  70.87      35.2    9517
#
#                      type
# ...

# %%
professions.rename(columns = {'women':'womens','prestige':'prestiges'},inplace =True)

# %%
professions.rename( index = {'accountants':'bookkeepers','general.managers':'managers'},inplace =True)

# %%
professions
# Out:
#                      education  income  womens  prestiges  census  type
# name
# gov.administrators       13.11   12351   11.16       68.8    1113  prof
# managers                 12.26   25879    4.02       69.1    1130  prof
# bookkeepers              12.77    9271   15.70       63.4    1171  prof
# purchasing.officers      11.42    8865    9.11       56.8    1175  prof
# chemists                 14.62    8403   11.68       73.5    2111  prof
# ...                        ...     ...     ...        ...     ...   ...
# bus.drivers               7.58    5562    9.47       35.9    9171    bc
# taxi.drivers              7.93    4224    3.59       25.1    9173    bc
# longshoremen              8.37    4753    0.00       26.1    9313    bc
# typesetters              10.00    6462   13.58       42.2    9511    bc
# bookbinders               8.55    3617   70.87       35.2    9517    bc
#
# [102 rows x 6 columns]

# %%
professions.head()
# Out:
#                      education  income  womens  prestiges  census  type
# name
# gov.administrators       13.11   12351   11.16       68.8    1113  prof
# managers                 12.26   25879    4.02       69.1    1130  prof
# bookkeepers              12.77    9271   15.70       63.4    1171  prof
# purchasing.officers      11.42    8865    9.11       56.8    1175  prof
# chemists                 14.62    8403   11.68       73.5    2111  prof

# %%
professions1.head()
# Out:
#                      education  income  women  prestige  census  type
# name
# gov.administrators       13.11   12351  11.16      68.8    1113  prof
# general.managers         12.26   25879   4.02      69.1    1130  prof
# accountants              12.77    9271  15.70      63.4    1171  prof
# purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# chemists                 14.62    8403  11.68      73.5    2111  prof

# %%
frame = pd.read_csv("C:\ML\data\insurance.csv")

# %%
frame.head()
# Out:
#    ID  District   Group    Age  Holders  Claims
# 0   1         1     <1l    <25      197      38
# 1   2         1     <1l  25-29      264      35
# 2   3         1     <1l  30-35      246      20
# 3   4         1     <1l    >35     1680     156
# 4   5         1  1-1.5l    <25      284      63

# %%
frame.loc[2,'Claims']
# Out:
# 20

# %%
frame.loc[2,'Claims'] = 19

# %%
frame.head()
# Out:
#    ID  District   Group    Age  Holders  Claims
# 0   1         1     <1l    <25      197      38
# 1   2         1     <1l  25-29      264      35
# 2   3         1     <1l  30-35      246      19
# 3   4         1     <1l    >35     1680     156
# 4   5         1  1-1.5l    <25      284      63

# %%
frame.loc[2,'Claims'] +=1

# %%
frame.head()
# Out:
#    ID  District   Group    Age  Holders  Claims
# 0   1         1     <1l    <25      197      38
# 1   2         1     <1l  25-29      264      35
# 2   3         1     <1l  30-35      246      23
# 3   4         1     <1l    >35     1680     156
# 4   5         1  1-1.5l    <25      284      63

# %%
young25 = frame["Age"] =="<25"

# %%
frame.where(young25).dropna()
# Out:
#       ID  District   Group  Age  Holders  Claims
# 0    1.0       1.0     <1l  <25    197.0    38.0
# 4    5.0       1.0  1-1.5l  <25    284.0    63.0
# 8    9.0       1.0  1.5-2l  <25    133.0    19.0
# 12  13.0       1.0     >2l  <25     24.0     4.0
# 16  17.0       2.0     <1l  <25     85.0    22.0
# 20  21.0       2.0  1-1.5l  <25    149.0    25.0
# 24  25.0       2.0  1.5-2l  <25     66.0    14.0
# 28  29.0       2.0     >2l  <25      9.0     4.0
# 32  33.0       3.0     <1l  <25     35.0     5.0
# 36  37.0       3.0  1-1.5l  <25     53.0    10.0
# 40  41.0       3.0  1.5-2l  <25     24.0     8.0
# 44  45.0       3.0     >2l  <25      7.0     3.0
# 48  49.0       4.0     <1l  <25     20.0     2.0
# 52  53.0       4.0  1-1.5l  <25     31.0     7.0
# 56  57.0       4.0  1.5-2l  <25     18.0     5.0
# 60  61.0       4.0     >2l  <25      3.0     0.0

# %%
frame[young25].head()
# Out:
#     ID  District   Group  Age  Holders  Claims
# 0    1         1     <1l  <25      197      38
# 4    5         1  1-1.5l  <25      284      63
# 8    9         1  1.5-2l  <25      133      19
# 12  13         1     >2l  <25       24       4
# 16  17         2     <1l  <25       85      22

# %%
frame.loc[young25,"Holders"].head()
# Out:
# 0     197
# 4     284
# 8     133
# 12     24
# 16     85
# Name: Holders, dtype: int64

# %%
frame.loc[young25,"Holders"] +100
# Out:
# 0     297
# 4     384
# 8     233
# 12    124
# 16    185
# 20    249
# 24    166
# 28    109
# 32    135
# 36    153
# 40    124
# 44    107
# 48    120
# 52    131
# 56    118
# 60    103
# Name: Holders, dtype: int64

# %%
frame.loc[young25,"Holders"] = frame.loc[young25,"Holders"]+100

# %%
frame
# Out:
#     ID  District   Group    Age  Holders  Claims
# 0    1         1     <1l    <25      297      38
# 1    2         1     <1l  25-29      264      35
# 2    3         1     <1l  30-35      246      23
# 3    4         1     <1l    >35     1680     156
# 4    5         1  1-1.5l    <25      384      63
# ..  ..       ...     ...    ...      ...     ...
# 59  60         4  1.5-2l    >35      344      63
# 60  61         4     >2l    <25      103       0
# 61  62         4     >2l  25-29       16       6
# 62  63         4     >2l  30-35       25       8
# 63  64         4     >2l    >35      114      33
#
# [64 rows x 6 columns]

# %%
frame.loc[young25,"Holders"]+=1000

# %%
frame
# Out:
#     ID  District   Group    Age  Holders  Claims
# 0    1         1     <1l    <25     1297      38
# 1    2         1     <1l  25-29      264      35
# 2    3         1     <1l  30-35      246      23
# 3    4         1     <1l    >35     1680     156
# 4    5         1  1-1.5l    <25     1384      63
# ..  ..       ...     ...    ...      ...     ...
# 59  60         4  1.5-2l    >35      344      63
# 60  61         4     >2l    <25     1103       0
# 61  62         4     >2l  25-29       16       6
# 62  63         4     >2l  30-35       25       8
# 63  64         4     >2l    >35      114      33
#
# [64 rows x 6 columns]

# %%
frame
# Out:
#     ID  District   Group    Age  Holders  Claims
# 0    1         1     <1l    <25     1297      38
# 1    2         1     <1l  25-29      264      35
# 2    3         1     <1l  30-35      246      23
# 3    4         1     <1l    >35     1680     156
# 4    5         1  1-1.5l    <25     1384      63
# ..  ..       ...     ...    ...      ...     ...
# 59  60         4  1.5-2l    >35      344      63
# 60  61         4     >2l    <25     1103       0
# 61  62         4     >2l  25-29       16       6
# 62  63         4     >2l  30-35       25       8
# 63  64         4     >2l    >35      114      33
#
# [64 rows x 6 columns]
