# %%
import pandas as pd
import numpy as np

# %%
prof = pd.read_csv("C:\Ml\data\Prestige.csv")

# %%
prof
# Out:
#                     name  education  income  women  prestige  census  type
# 0     gov.administrators      13.11   12351  11.16      68.8    1113  prof
# 1       general.managers      12.26   25879   4.02      69.1    1130  prof
# 2            accountants      12.77    9271  15.70      63.4    1171  prof
# 3    purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# 4               chemists      14.62    8403  11.68      73.5    2111  prof
# ..                   ...        ...     ...    ...       ...     ...   ...
# 97           bus.drivers       7.58    5562   9.47      35.9    9171    bc
# 98          taxi.drivers       7.93    4224   3.59      25.1    9173    bc
# 99          longshoremen       8.37    4753   0.00      26.1    9313    bc
# 100          typesetters      10.00    6462  13.58      42.2    9511    bc
# 101          bookbinders       8.55    3617  70.87      35.2    9517    bc
#
# [102 rows x 7 columns]

# %%
 dict = { 'name' : 'data scientist',
'education' : np.NaN,
'income' : np.NaN,
'women' : np.NaN,
'prestige' : np.NaN,
'census' : np.NaN,
'type' : np.NaN}

# %%
dict
# Out:
# {'name': 'data scientist',
#  'education': nan,
#  'income': nan,
#  'women': nan,
#  'prestige': nan,
#  'census': nan,
#  'type': nan}

# %%
prof.append(dict, ignore_index=True)
# Out:
#                     name  education   income  women  prestige  census  type
# 0     gov.administrators      13.11  12351.0  11.16      68.8  1113.0  prof
# 1       general.managers      12.26  25879.0   4.02      69.1  1130.0  prof
# 2            accountants      12.77   9271.0  15.70      63.4  1171.0  prof
# 3    purchasing.officers      11.42   8865.0   9.11      56.8  1175.0  prof
# 4               chemists      14.62   8403.0  11.68      73.5  2111.0  prof
# ..                   ...        ...      ...    ...       ...     ...   ...
# 98          taxi.drivers       7.93   4224.0   3.59      25.1  9173.0    bc
# 99          longshoremen       8.37   4753.0   0.00      26.1  9313.0    bc
# 100          typesetters      10.00   6462.0  13.58      42.2  9511.0    bc
# 101          bookbinders       8.55   3617.0  70.87      35.2  9517.0    bc
# 102       data scientist        NaN      NaN    NaN       NaN     NaN   NaN
#
# [102 rows x 7 columns]

# %%
taxi = prof[prof.name == 'taxi.drivers']

# %%
taxi
# Out:
#             name  education  income  women  prestige  census type
# 98  taxi.drivers       7.93    4224   3.59      25.1    9173   bc

# %%
womenpow50 = prof[prof.women >= 50]

# %%
policeman
# Out:
# Empty DataFrame
# Columns: [name, education, income, women, prestige, census, type]
# Index: []

# %% [markdown]
# womenpow50

# %%
womenpow50
# Out:
#                         name  education  income  women  prestige  census  type
# 13                economists      14.44    8049  57.31      62.2    2311  prof
# 15            social.workers      14.21    6336  54.77      55.1    2331  prof
# 17                librarians      14.15    6112  77.10      58.1    2351  prof
# 21   primary.school.teachers      13.62    5648  83.78      59.6    2731  prof
# 26                    nurses      12.46    4614  96.12      64.7    3131  prof
# 27             nursing.aides       9.45    3485  76.14      34.9    3135    bc
# 28          physio.therapsts      13.62    5092  82.66      72.1    3137  prof
# 30       medical.technicians      12.79    5180  76.04      67.5    3156    wc
# 34               secretaries      11.59    4036  97.51      46.0    4111    wc
# 35                   typists      11.49    3148  95.97      41.9    4113    wc
# 36               bookkeepers      11.32    4348  68.24      49.4    4131    wc
# ...

# %%
womenpon10 = prof[prof.women <10]
sorted womenpon10
# Out:
#   File "<ipython-input-36-95de40166dab>", line 2
#     sorted womenpon10
#                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# .sort (by ='women')

# %%
womenpon10.sort_values (by ='women', ascending=False)
# Out:
#                          name  education  income  women  prestige  census  \
# 97                bus.drivers       7.58    5562   9.47      35.9    9171
# 3         purchasing.officers      11.42    8865   9.11      56.8    1175
# 33                   athletes      11.44    8206   8.13      54.1    3373
# 11                draughtsmen      12.30    7059   7.83      60.0    2163
# 42              mail.carriers       9.22    5511   7.62      36.1    4172
# 52                   newsboys       9.62     918   7.00      14.8    5143
# 25   osteopaths.chiropractors      14.71   17498   6.91      68.4    3117
# 61          funeral.directors      10.57    7869   6.01      54.9    6141
# 80           aircraft.workers       8.78    6573   5.78      43.7    8515
# 78                    welders       7.92    6477   5.17      41.8    8335
# 16                    lawyers      15.77   19263   5.13      82.3    2343
# 5                  physicists      15.64   11030   5.13      77.6    2113
# ...

# %%
prof
# Out:
#                     name  education  income  women  prestige  census  type
# 0     gov.administrators      13.11   12351  11.16      68.8    1113  prof
# 1       general.managers      12.26   25879   4.02      69.1    1130  prof
# 2            accountants      12.77    9271  15.70      63.4    1171  prof
# 3    purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# 4               chemists      14.62    8403  11.68      73.5    2111  prof
# ..                   ...        ...     ...    ...       ...     ...   ...
# 97           bus.drivers       7.58    5562   9.47      35.9    9171    bc
# 98          taxi.drivers       7.93    4224   3.59      25.1    9173    bc
# 99          longshoremen       8.37    4753   0.00      26.1    9313    bc
# 100          typesetters      10.00    6462  13.58      42.2    9511    bc
# 101          bookbinders       8.55    3617  70.87      35.2    9517    bc
#
# [102 rows x 7 columns]

# %%
prof.drop(99, inplace = True)
prof.tail()
# Out:
#                        name  education  income  women  prestige  census
# 93                 plumbers       8.33    6928   0.61      42.9    8791
# 94   construction.labourers       7.52    3910   1.09      26.5    8798
# 95                   pilots      12.27   14032   0.58      66.1    9111
# 97              bus.drivers       7.58    5562   9.47      35.9    9171
# 100             typesetters      10.00    6462  13.58      42.2    9511

# %%
prof.append(taxi,)
# Out:
#                     name  education  income  women  prestige  census  type
# 0     gov.administrators      13.11   12351  11.16      68.8    1113  prof
# 1       general.managers      12.26   25879   4.02      69.1    1130  prof
# 2            accountants      12.77    9271  15.70      63.4    1171  prof
# 3    purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# 4               chemists      14.62    8403  11.68      73.5    2111  prof
# ..                   ...        ...     ...    ...       ...     ...   ...
# 95                pilots      12.27   14032   0.58      66.1    9111  prof
# 97           bus.drivers       7.58    5562   9.47      35.9    9171    bc
# 99          longshoremen       8.37    4753   0.00      26.1    9313    bc
# 100          typesetters      10.00    6462  13.58      42.2    9511    bc
# 98          taxi.drivers       7.93    4224   3.59      25.1    9173    bc
#
# [100 rows x 7 columns]

# %%
prof.drop(columns = 'census')
# Out:
#                        name  education  income  women  prestige  type
# 0        gov.administrators      13.11   12351  11.16      68.8  prof
# 1          general.managers      12.26   25879   4.02      69.1  prof
# 2               accountants      12.77    9271  15.70      63.4  prof
# 3       purchasing.officers      11.42    8865   9.11      56.8  prof
# 4                  chemists      14.62    8403  11.68      73.5  prof
# ..                      ...        ...     ...    ...       ...   ...
# 94   construction.labourers       7.52    3910   1.09      26.5    bc
# 95                   pilots      12.27   14032   0.58      66.1  prof
# 97              bus.drivers       7.58    5562   9.47      35.9    bc
# 99             longshoremen       8.37    4753   0.00      26.1    bc
# 100             typesetters      10.00    6462  13.58      42.2    bc
#
# [99 rows x 6 columns]

# %%
del prof["type"]

# %%
prof
# Out:
#                        name  education  income  women  prestige  census
# 0        gov.administrators      13.11   12351  11.16      68.8    1113
# 1          general.managers      12.26   25879   4.02      69.1    1130
# 2               accountants      12.77    9271  15.70      63.4    1171
# 3       purchasing.officers      11.42    8865   9.11      56.8    1175
# 4                  chemists      14.62    8403  11.68      73.5    2111
# ..                      ...        ...     ...    ...       ...     ...
# 94   construction.labourers       7.52    3910   1.09      26.5    8798
# 95                   pilots      12.27   14032   0.58      66.1    9111
# 97              bus.drivers       7.58    5562   9.47      35.9    9171
# 99             longshoremen       8.37    4753   0.00      26.1    9313
# 100             typesetters      10.00    6462  13.58      42.2    9511
#
# [99 rows x 6 columns]
