# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
country = pd.read_csv("C:\ML\data\St.csv", usecols=['Country'],squeeze = True)

# %%
country
# Out:
# 0         United States
# 1        United Kingdom
# 2        United Kingdom
# 3         United States
# 4           Switzerland
#               ...
# 51387     United States
# 51388         Venezuela
# 51389            Canada
# 51390     United States
# 51391           Ireland
# Name: Country, Length: 51392, dtype: object

# %%
country=country.dropna()

# %%
country.dropna()
# Out:
# 0         United States
# 1        United Kingdom
# 2        United Kingdom
# 3         United States
# 4           Switzerland
#               ...
# 51387     United States
# 51388         Venezuela
# 51389            Canada
# 51390     United States
# 51391           Ireland
# Name: Country, Length: 51392, dtype: object

# %%
country.sorted
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-a49252a0c7d3> in <module>
# ----> 1 country.sorted
#
# C:\ML\pandas\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'sorted'

# %%
sorted(country)
# Out:
# ['Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
# ...

# %%
'Nna' in country.values
# Out:
# False

# %%
'Poland' in country.values
# Out:
# True

# %%
'Spain' in country
# Out:
# False

# %%
'Spain' in country.values
# Out:
# True

# %%
'Wonderland' in country.values
# Out:
# False
