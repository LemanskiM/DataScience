# %%
import pandas as pd
import numpy as np

# %%
fortune = pd.read_csv("C:\python\data\Fortune_500_2017.csv", usecols=['Rank','Title','Industry','Hqlocation','Sector'])

# %%
fortune.head()
# Out:
#    Rank               Title       Sector  \
# 0     1             Walmart    Retailing
# 1     2  Berkshire Hathaway   Financials
# 2     3               Apple   Technology
# 3     4         Exxon Mobil       Energy
# 4     5            McKesson  Wholesalers
#
#                                    Industry         Hqlocation
# 0                     General Merchandisers    Bentonville, AR
# 1  Insurance: Property and Casualty (Stock)          Omaha, NE
# 2               Computers, Office Equipment      Cupertino, CA
# 3                        Petroleum Refining         Irving, TX
# 4                  Wholesalers: Health Care  San Francisco, CA

# %%
fortune['Sector'] = fortune['Sector'].str.upper()

# %%
fortune
# Out:
#      Rank               Title                      Sector  \
# 0       1             Walmart                   RETAILING
# 1       2  Berkshire Hathaway                  FINANCIALS
# 2       3               Apple                  TECHNOLOGY
# 3       4         Exxon Mobil                      ENERGY
# 4       5            McKesson                 WHOLESALERS
# ..    ...                 ...                         ...
# 495   496       Michaels Cos.                   RETAILING
# 496   497       Toll Brothers  ENGINEERING & CONSTRUCTION
# 497   498               Yahoo                  TECHNOLOGY
# 498   499       Vistra Energy                      ENERGY
# 499   500      ABM Industries           BUSINESS SERVICES
#
#                                      Industry         Hqlocation
# 0                       General Merchandisers    Bentonville, AR
# 1    Insurance: Property and Casualty (Stock)          Omaha, NE
# 2                 Computers, Office Equipment      Cupertino, CA
# ...

# %%
fortune['Industry'] = fortune['Industry'].str.lower()

# %%
fortune
# Out:
#      Rank               Title                      Sector  \
# 0       1             Walmart                   RETAILING
# 1       2  Berkshire Hathaway                  FINANCIALS
# 2       3               Apple                  TECHNOLOGY
# 3       4         Exxon Mobil                      ENERGY
# 4       5            McKesson                 WHOLESALERS
# ..    ...                 ...                         ...
# 495   496       Michaels Cos.                   RETAILING
# 496   497       Toll Brothers  ENGINEERING & CONSTRUCTION
# 497   498               Yahoo                  TECHNOLOGY
# 498   499       Vistra Energy                      ENERGY
# 499   500      ABM Industries           BUSINESS SERVICES
#
#                                      Industry         Hqlocation
# 0                       general merchandisers    Bentonville, AR
# 1    insurance: property and casualty (stock)          Omaha, NE
# 2                 computers, office equipment      Cupertino, CA
# ...

# %%
fortune[fortune['Industry'].str.contains('comp')]
# Out:
#      Rank                Title      Sector  \
# 2       3                Apple  TECHNOLOGY
# 27     28            Microsoft  TECHNOLOGY
# 40     41    Dell Technologies  TECHNOLOGY
# 46     47                Intel  TECHNOLOGY
# 60     61                   HP  TECHNOLOGY
# 80     81               Oracle  TECHNOLOGY
# 118   119             Qualcomm  TECHNOLOGY
# 151   152        Jabil Circuit  TECHNOLOGY
# 161   162                Xerox  TECHNOLOGY
# 205   206    Texas Instruments  TECHNOLOGY
# 216   217      Western Digital  TECHNOLOGY
# 225   226    Micron Technology  TECHNOLOGY
# 264   265    Applied Materials  TECHNOLOGY
# 325   326       salesforce.com  TECHNOLOGY
# 386   387               Nvidia  TECHNOLOGY
# 405   406  Activision Blizzard  TECHNOLOGY
# 408   409                  NCR  TECHNOLOGY
# 413   414              Sanmina  TECHNOLOGY
# 439   440         Lam Research  TECHNOLOGY
# 442   443        Adobe Systems  TECHNOLOGY
# 464   465             Symantec  TECHNOLOGY
# ...

# %%
fortune
# Out:
#      Rank               Title                      Sector  Industry  \
# 0       1             Walmart                   RETAILING     False
# 1       2  Berkshire Hathaway                  FINANCIALS     False
# 2       3               Apple                  TECHNOLOGY      True
# 3       4         Exxon Mobil                      ENERGY     False
# 4       5            McKesson                 WHOLESALERS     False
# ..    ...                 ...                         ...       ...
# 495   496       Michaels Cos.                   RETAILING     False
# 496   497       Toll Brothers  ENGINEERING & CONSTRUCTION     False
# 497   498               Yahoo                  TECHNOLOGY     False
# 498   499       Vistra Energy                      ENERGY     False
# 499   500      ABM Industries           BUSINESS SERVICES     False
#
#             Hqlocation
# 0      Bentonville, AR
# 1            Omaha, NE
# 2        Cupertino, CA
# 3           Irving, TX
# 4    San Francisco, CA
# ...

# %%
fortune[['City','State']] = fortune['Hqlocation'].str.split(',',expand = True,)

# %%
fortune
# Out:
#      Rank               Title                      Sector  \
# 0       1             Walmart                   RETAILING
# 1       2  Berkshire Hathaway                  FINANCIALS
# 2       3               Apple                  TECHNOLOGY
# 3       4         Exxon Mobil                      ENERGY
# 4       5            McKesson                 WHOLESALERS
# ..    ...                 ...                         ...
# 495   496       Michaels Cos.                   RETAILING
# 496   497       Toll Brothers  ENGINEERING & CONSTRUCTION
# 497   498               Yahoo                  TECHNOLOGY
# 498   499       Vistra Energy                      ENERGY
# 499   500      ABM Industries           BUSINESS SERVICES
#
#                                      Industry         Hqlocation  \
# 0                       general merchandisers    Bentonville, AR
# 1    insurance: property and casualty (stock)          Omaha, NE
# 2                 computers, office equipment      Cupertino, CA
# ...

# %%
def BulidShortcut(row):
    pob = row["Industry"]
    result = ''
    for i in pob.split(' '):
        result += i[0]
    return result

# %%
BulidShortcut({'Industry':'Factory Underbewspaper'})
# Out:
# 'FU'

# %%
fortune['IndustryShort'] = fortune.apply(BulidShortcut,axis=1)

# %%
fortune
# Out:
#      Rank               Title                      Sector  \
# 0       1             Walmart                   RETAILING
# 1       2  Berkshire Hathaway                  FINANCIALS
# 2       3               Apple                  TECHNOLOGY
# 3       4         Exxon Mobil                      ENERGY
# 4       5            McKesson                 WHOLESALERS
# ..    ...                 ...                         ...
# 495   496       Michaels Cos.                   RETAILING
# 496   497       Toll Brothers  ENGINEERING & CONSTRUCTION
# 497   498               Yahoo                  TECHNOLOGY
# 498   499       Vistra Energy                      ENERGY
# 499   500      ABM Industries           BUSINESS SERVICES
#
#                                      Industry         Hqlocation  \
# 0                       general merchandisers    Bentonville, AR
# 1    insurance: property and casualty (stock)          Omaha, NE
# 2                 computers, office equipment      Cupertino, CA
# ...
