# %%
import pandas as pd
import numpy as np

# %%
fortune = pd.read_csv("C:\ML\data\Fortune_500_2017.csv")

# %%
fh = fortune.head()

# %%
fh
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2     3               Apple              http://www.apple.com     116000
# 3     4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4     5            McKesson           http://www.mckesson.com      68000
#
#         Sector                                  Industry         Hqlocation  \
# 0    Retailing                     General Merchandisers    Bentonville, AR
# 1   Financials  Insurance: Property and Casualty (Stock)          Omaha, NE
# 2   Technology               Computers, Office Equipment      Cupertino, CA
# 3       Energy                        Petroleum Refining         Irving, TX
# 4  Wholesalers                  Wholesalers: Health Care  San Francisco, CA
#
#                    Hqaddr         Hqcity Hqstate  ...  \
# ...

# %%
fortune.set_index('Rank',inplace =True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-8e518b41646d> in <module>
# ----> 1 fortune.set_index('Rank',inplace =True)
#
# C:\ML\pandas\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4394
#    4395         if missing:
# -> 4396             raise KeyError("None of {} are in the columns".format(missing))
#    4397
#    4398         if inplace:
#
# KeyError: "None of ['Rank'] are in the columns"

# %%
# Out:
#                    Title                           Website  Employees  \
# Rank
# 1                Walmart            http://www.walmart.com    2300000
# 2     Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 3                  Apple              http://www.apple.com     116000
# 4            Exxon Mobil         http://www.exxonmobil.com      72700
# 5               McKesson           http://www.mckesson.com      68000
# ...                  ...                               ...        ...
# 496        Michaels Cos.           http://www.michaels.com      31000
# 497        Toll Brothers       http://www.tollbrothers.com       4200
# 498                Yahoo              http://www.yahoo.com       8500
# 499        Vistra Energy       http://www.vistraenergy.com       4431
# 500       ABM Industries                http://www.abm.com     110000
#
#                           Sector                                  Industry  \
# Rank
# ...

# %%
fortune.loc[100:105]
# Out:
#                             Title                    Website  Employees  \
# Rank
# 100         Capital One Financial  http://www.capitalone.com      47300
# 101      Twenty-First Century Fox        http://www.21cf.com      21500
# 102                          USAA        http://www.usaa.com      29943
# 103           World Fuel Services     http://www.wfscorp.com       5000
# 104   Philip Morris International         http://www.pmi.com      79500
# 105                         Deere   http://www.johndeere.com      56767
#
#                          Sector                                  Industry  \
# Rank
# 100                  Financials                          Commercial Banks
# 101                       Media                             Entertainment
# 102                  Financials  Insurance: Property and Casualty (Stock)
# 103                      Energy                                    Energy
# 104   Food, Beverages & Tobacco                                   Tobacco
# ...

# %%
fortune[['Title','Employees']].loc[100:105]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-cdad6c0edc7c> in <module>
# ----> 1 fortune[['Title','Employees']].loc[100:105]
#
# C:\ML\pandas\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# C:\ML\pandas\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
# ...

# %%
fortune.reset_index(inplace=True)

# %%
fortune.set_index('Title', inplace=True)

# %%
fortune
# Out:
#                     Rank                           Website  Employees  \
# Title
# Walmart                1            http://www.walmart.com    2300000
# Berkshire Hathaway     2  http://www.berkshirehathaway.com     367700
# Apple                  3              http://www.apple.com     116000
# Exxon Mobil            4         http://www.exxonmobil.com      72700
# McKesson               5           http://www.mckesson.com      68000
# ...                  ...                               ...        ...
# Michaels Cos.        496           http://www.michaels.com      31000
# Toll Brothers        497       http://www.tollbrothers.com       4200
# Yahoo                498              http://www.yahoo.com       8500
# Vistra Energy        499       http://www.vistraenergy.com       4431
# ABM Industries       500                http://www.abm.com     110000
#
#                                         Sector  \
# Title
# Walmart                              Retailing
# ...

# %%
fortune.sort_index()
# Out:
#                         Rank                      Website  Employees  \
# Title
# 3M                        94            http://www.3m.com      91584
# A-Mark Precious Metals   395         http://www.amark.com         83
# ABM Industries           500           http://www.abm.com     110000
# ADP                      240           http://www.adp.com      57000
# AECOM                    161         http://www.aecom.com      87000
# ...                      ...                          ...        ...
# Yum China Holdings       399       http://ir.yumchina.com     420000
# Zimmer Biomet Holdings   352  http://www.zimmerbiomet.com      18500
# eBay                     310          http://www.ebay.com      12600
# iHeartMedia              426   http://www.iheartmedia.com      18700
# salesforce.com           326    http://www.salesforce.com      25000
#
#                                                Sector  \
# Title
# 3M                                        Industrials
# ...

# %%
 x =fortune.sort_values(by = 'Employees', ascending=False).head(10)

# %%
fortune.loc[0:10]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-7e487f3d82ab> in <module>
# ----> 1 fortune.loc[0:10]
#
# C:\ML\pandas\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# C:\ML\pandas\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1795         if isinstance(key, slice):
#    1796             self._validate_key(key, axis)
# -> 1797             return self._get_slice_axis(key, axis=axis)
#    1798         elif com.is_bool_indexer(key):
#    1799             return self._getbool_axis(key, axis=axis)
#
# ...

# %%
fortune = pd.read_csv("C:\ML\data\Fortune_500_2017.csv")

# %%
fortune.loc[0:10]
# Out:
#     Rank               Title                           Website  Employees  \
# 0      1             Walmart            http://www.walmart.com    2300000
# 1      2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2      3               Apple              http://www.apple.com     116000
# 3      4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4      5            McKesson           http://www.mckesson.com      68000
# 5      6  UnitedHealth Group  http://www.unitedhealthgroup.com     230000
# 6      7          CVS Health          http://www.cvshealth.com     204000
# 7      8      General Motors                 http://www.gm.com     225000
# 8      9                AT&T                http://www.att.com     268540
# 9     10          Ford Motor               http://www.ford.com     201000
# 10    11   AmerisourceBergen  http://www.amerisourcebergen.com      18500
#
#                     Sector                                  Industry  \
# ...
